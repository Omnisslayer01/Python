# %%
name="Akshay Chaudhary"
index=0
for i in name:
 print("name[", index, "] = ", i)
 index=index+1
# Out:
# name[ 0 ] =  A
# name[ 1 ] =  k
# name[ 2 ] =  s
# name[ 3 ] =  h
# name[ 4 ] =  a
# name[ 5 ] =  y
# name[ 6 ] =
# name[ 7 ] =  C
# name[ 8 ] =  h
# name[ 9 ] =  a
# name[ 10 ] =  u
# name[ 11 ] =  d
# name[ 12 ] =  h
# name[ 13 ] =  a
# name[ 14 ] =  r
# name[ 15 ] =  y

# %%
# Out:
# Value of a is: 3
# Value of b is: 2

# %%
name="Pankaj Phadtade"
for i in name:
    print(i)
# Out:
# P
# a
# n
# k
# a
# j
#
# P
# h
# a
# d
# t
# a
# d
# e

# %%
code= "Program"
print(code[-1:])
# Out:
# m

# %%
str = "Welcome!"
str[0]="p"
print(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 str = "Welcome!"
# ----> 2 str[0]="p"
#       3 print(str)
#
# TypeError: 'str' object does not support item assignment

# %%
color="red"

if color=="red":
    print("stop")
if color=="green":
    print("go")
if color=="yellow":
    print("go slow")
# Out:
# stop
